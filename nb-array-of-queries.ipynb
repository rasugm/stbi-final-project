# %%
# from itertools import combinations
from pymongo import MongoClient
import json
# from bson import ObjectId

client = MongoClient('mongodb://root:admin123%23@localhost:27017/?authMechanism=SCRAM-SHA-1&authSource=admin')
db = client['kpu']
collection_dataset_caleg_training = db['col_dataset_caleg']

exclude_columns = ["_id", "original_id", "gelar_1_acronym", "nama_dapil"]

# Prepare projection to exclude specified columns
projection = {column: 0 for column in exclude_columns}

data_collection = list(collection_dataset_caleg_training.find({}, projection))
data_col_json = json.loads(json.dumps(data_collection))
data_col_json
# data_dua = [{
#     "dapil": "dewan perwakilan daerah kabupaten kota",
#     "provinsi": "sumatera selatan",
#     "nama_dapil": "empat lawang 2",
#     "nama_dapil_label": "empat lawang dua",
#     "nomor_urut_partai": 7,
#     "nomor_urut_partai_label": "tujuh",
#     "nama_partai_acronym": "berkarya",
#     "nama_partai": "partai berkarya",
#     "nomor_urut_caleg": 2,
#     "nomor_urut_caleg_label": "dua",
#     "first_name": "dadang",
#     "last_name": "wijaya",
#     "gelar_1_acronym": "sp",
#     "gelar_1": "sp",
#     "middle_name": "batra sunda",
#     "jenis_kelamin": "laki-laki",
#     "caleg_tahun": 2019
# }]

# data
# data_dua

# print(data)
# print(data_dua)

# Generate search queries
# Define the fields to combine
# fields = ['provinsi', 'nama_partai', 'first_name', 'last_name', 'middle_name']

# Generate search queries
queries = []

for data in data_col_json:
    for i in range(1, len(fields) + 1):
        combined_fields = fields[:i]
        if len(combined_fields) > 1:  # Skip if only one field in combination
            query_parts = []
            for field in combined_fields:
                if field in data:
                    query_parts.append(data[field])
            if query_parts:
                query = ' '.join(query_parts)
                queries.append(query)


# for i in range(1, len(data[0]) + 1):
#     for combination in combinations(data[0].keys(), i):
#         query_parts = []
#         for field in combination:
#             value = data[0][field]
#             if isinstance(value, int):
#                 query_parts.append(f"{field.replace('_', ' ')} {value}")  # Append additional text for integer values
#             else:
#                 query_parts.append(value)
#         query = ' '.join(query_parts)
#         queries.append(query)

# exclude_fields = ["dapil", "jenis_kelamin", "caleg_tahun", "gelar_1", "nomor_urut_caleg"]
# fields = data[0].keys()

# for i in range(1, len(fields) + 1):
#     for combination in combinations(fields, i):
#         if not any(field in exclude_fields for field in combination):
#             query_parts = []
#             for field in combination:
#                 value = data[0][field]
#                 if isinstance(value, int):
#                     query_parts.append(f"{field.replace('_', ' ')} {value}")  # Append additional text for integer values
#                 else:
#                     query_parts.append(value)
#             query = ' '.join(query_parts)
#             queries.append(query)

# len(queries)
unique_array = []
[unique_array.append(x) for x in queries if x not in unique_array]
unique_array
# Out:
# ['daerah istimewa yogyakarta partai kebangkitan bangsa',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa ahmad',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa ahmad musyakir',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa drs.',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa drs. sw',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa drs. sw h. suharyanto',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa martha',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa martha abram',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa yunianto',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa yunianto setiawan',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa yunianto setiawan budi',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa ir.',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa ir. santoso',
#  'daerah istimewa yogyakarta partai kebangkitan bangsa ir. santoso helmi',
# ...

# %%
# len(unique_array)
import pandas as pd

array_queries

def map_to_dataframe(queries):
    # Create a list of dictionaries containing 'qid' and 'vector'
    mapped_queries = [{'qid': idx+1, 'vector': query} for idx, query in enumerate(queries)]
    # Convert the list of dictionaries to a DataFrame
    array_queries = mapped_queries
    return pd.DataFrame(mapped_queries)

testing_queries = map_to_dataframe(queries)

array_queries[0]

# testing_queries.to_csv('testing_queries.csv', index=False)
# import csv

# # File path to save CSV
# csv_file_path = 'queries_all.csv'

# with open(csv_file_path, 'w', newline='') as csvfile:
#     csv_writer = csv.writer(csvfile)
#     csv_writer.writerows([unique_array])
# Out:
# [{'qid': 1, 'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa'},
#  {'qid': 2,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa ahmad'},
#  {'qid': 3,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa ahmad musyakir'},
#  {'qid': 4,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa ahmad musyakir'},
#  {'qid': 5, 'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa'},
#  {'qid': 6,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa drs.'},
#  {'qid': 7,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa drs. sw'},
#  {'qid': 8,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa drs. sw h. suharyanto'},
#  {'qid': 9, 'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa'},
#  {'qid': 10,
#   'vector': 'daerah istimewa yogyakarta partai kebangkitan bangsa martha'},
#  {'qid': 11,
# ...
