# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import json
import csv

from bson import ObjectId

# Connect to MongoDB
client = MongoClient('mongodb://root:admin123%23@localhost:27017/?authMechanism=SCRAM-SHA-1&authSource=admin')
db = client['kpu']
collection_dataset_caleg_training = db['col_dataset_caleg_text']

# Retrieve data from MongoDB collection
data_collection = list(collection_dataset_caleg_training.find())

# Convert ObjectId to string
for data in data_collection:
    data['_id'] = str(data['_id'])
    data['original_id'] = str(data['original_id'])

# Print the modified data_collection
documents = json.loads(json.dumps(data_collection))

documents

# # # LOAD QUERY TESTING FROM CSV
# # Define the file path
# file_path = 'queries_all.csv'

# queries_array = []
# # Open the CSV file
# with open(file_path, 'r') as file:
#     # Create a CSV reader object
#     csv_reader = csv.reader(file)

#     for row in csv_reader:
#         queries_array.append(row)  # Do whatever you need with the row data

# queries = queries_array[0]

# # queries = ['document', 'test document']

# # Preprocessing
# def preprocess(text):
#     # Tokenization, stopword removal, stemming, etc.
#     return text.lower().split()

# # Create Document-Term Matrix (DTM)
# corpus = [doc['text'] for doc in documents]
# vectorizer = TfidfVectorizer(tokenizer=preprocess)
# dtm = vectorizer.fit_transform(corpus)

# # Query processing
# query_vectors = vectorizer.transform(queries)

# # Similarity calculation
# similarities = cosine_similarity(query_vectors, dtm)

# # Ranking
# ranked_docs_indices = np.argsort(-similarities, axis=1)  # Sort in descending order

# # Sample relevance judgments for evaluation
# relevance_judgments = {
#     'document': {'doc1', 'doc2', 'doc3', 'doc4'},
#     'test document': {'doc4'}
# }

# # Evaluation
# def evaluate_precision_recall_accuracy(ranked_docs_indices, relevance_judgments):
#     total_relevant = 0
#     total_retrieved = 0
#     total_relevant_retrieved = 0
#     total_correctly_classified = 0
#     total_documents = 0

#     for query, relevant_docs in relevance_judgments.items():
#         print("Query:", query)
#         retrieved_docs = set([documents[i]['_id'] for i in ranked_docs_indices[queries.index(query)]])
#         relevant_retrieved = relevant_docs.intersection(retrieved_docs)

#         total_relevant += len(relevant_docs)
#         total_retrieved += len(retrieved_docs)
#         total_relevant_retrieved += len(relevant_retrieved)

#         # Accuracy calculation
#         for doc in documents:
#             if doc['_id'] in relevant_docs and doc['_id'] in retrieved_docs:
#                 total_correctly_classified += 1
#             elif doc['_id'] not in relevant_docs and doc['_id'] not in retrieved_docs:
#                 total_correctly_classified += 1
#             total_documents += 1

#         # List document with TF-IDF representation and similarity score
#         for doc_id, index in zip(retrieved_docs, ranked_docs_indices[queries.index(query)]):
#             print("Document:", doc_id)
#             # print("TF-IDF Representation:", dtm[index])
#             print("Similarity Score:", similarities[queries.index(query)][index])
#             print()

#     precision = total_relevant_retrieved / total_retrieved if total_retrieved > 0 else 0
#     recall = total_relevant_retrieved / total_relevant
#     accuracy = total_correctly_classified / total_documents

#     return precision, recall, accuracy

# precision, recall, accuracy = evaluate_precision_recall_accuracy(ranked_docs_indices, relevance_judgments)
# # print("Precision:", precision)
# # print("Recall:", recall)
# # print("Accuracy:", accuracy)
# Out:
# [{'_id': '65f4838f55c3c7ebac0c908f',
#   'original_id': '65f47eb507431007d31605e5',
#   'text': 'daftar pilihan calon legislatif dewan perwakilan daerah provinsi daerah istimewa yogyakarta satu dengan nomor urut partai satu partai kebangkitan bangsa nomor urut calon satu ahmad musyakir s.t jenis kelamin laki-laki calon legislatif tahun 2019'},
#  {'_id': '65f4838f55c3c7ebac0c9090',
#   'original_id': '65f47eb507431007d31605e6',
#   'text': 'daftar pilihan calon legislatif dewan perwakilan daerah provinsi daerah istimewa yogyakarta satu dengan nomor urut partai satu partai kebangkitan bangsa nomor urut calon dua drs. sw h. suharyanto jenis kelamin laki-laki calon legislatif tahun 2019'},
#  {'_id': '65f4838f55c3c7ebac0c9091',
#   'original_id': '65f47eb507431007d31605e7',
# ...
